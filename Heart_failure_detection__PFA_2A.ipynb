# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b6ee4d05-5a2f-4f15-9c5b-a6ce0a19c2a9" name="files[]" multiple disabled />
#      <output id="result-b6ee4d05-5a2f-4f15-9c5b-a6ce0a19c2a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mehdinait","key":"13c7d9ae5bd705d77e953b2cbdef089e"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 65 May 23 06:44 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# ...
#      |████████████████████████████████| 61kB 1.9MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.6-cp36-none-any.whl size=72859 sha256=bc8c407d3bd472e881648a0927d1bef8833726b7379a947ec2975c5e1ead86ff
#   Stored in directory: /root/.cache/pip/wheels/57/4e/e8/bb28d035162fb8f17f8ca5d42c3230e284c6aa565b42b72674
# Successfully built kaggle
# ...
#   Found existing installation: kaggle 1.5.6
#     Uninstalling kaggle-1.5.6:
#       Successfully uninstalled kaggle-1.5.6
# ...

# %%
# !kaggle competitions download -c second-annual-data-science-bowl -p dataset
# Out:
# ...
# 100% 32.2G/32.2G [09:14<00:00, 75.0MB/s]
# 100% 32.2G/32.2G [09:14<00:00, 62.4MB/s]

# %%
cd dataset
# Out:
# [Errno 2] No such file or directory: 'dataset'
# /content/dataset

# %%
# !unzip \*.zip

# %%
import os

c=os.listdir("1001/study")
print(c)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-0b11a66c7211> in <module>()
#       1 import os
#       2
# ----> 3 c=os.listdir("1001/study")
#       4 print(c)
#
# FileNotFoundError: [Errno 2] No such file or directory: '1001/study'

# %%
cd 1000/study/sax_53
# Out:
# /content/dataset/test/test/1000/study/sax_53

# %%
pt=os.listdir("sax_53")

# %%
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 35.3MB 109kB/s
# ...

# %%
import pydicom
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
i=0

for path in c:  
  pt=os.listdir(path)
  ds = pydicom.dcmread(path+"/"+pt[0])
  image=ds.pixel_array
  cv2_imshow(image)
  i+=1
print(i)
# Out:
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A895160B8>
# <PIL.Image.Image image mode=L size=256x192 at 0x7F3A89495278>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A89512470>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A894A7A90>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A89516358>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A894954A8>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A89512EB8>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A894A7550>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A89516630>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A89495748>
# <PIL.Image.Image image mode=L size=192x256 at 0x7F3A895123C8>
# 11

# %% [markdown]
# Forget about all of this

# %%
cd test/test
# Out:
# /content/dataset/test/test

# %%
keys=os.listdir("test")

values=[]
max=0
sum=0
for key in keys:
  list=os.listdir("test/"+key+"/study")
  l=len(list)
  sum+=l
  if(l>max):
    max=l
  #print(list)
  values.append(list)
dic=dict(zip(keys,values))

# %%
print(keys)
# Out:
# ['1071', '1086', '707', '828', '744', '784', '936', '1107', '903', '854', '805', '1039', '852', '942', '966', '717', '770', '800', '823', '1005', '1065', '1119', '894', '851', '1045', '880', '781', '724', '1072', '804', '780', '807', '747', '1084', '719', '731', '819', '743', '817', '1006', '782', '838', '815', '701', '714', '934', '748', '1079', '866', '704', '1088', '853', '826', '790', '960', '883', '1059', '1015', '706', '908', '1128', '923', '1124', '849', '1133', '1090', '1057', '799', '1087', '822', '1103', '865', '814', '1113', '869', '1024', '850', '870', '1056', '726', '896', '888', '1047', '1068', '897', '831', '1032', '1082', '791', '1009', '915', '1093', '857', '751', '911', '1053', '1120', '793', '738', '777', '752', '919', '841', '1046', '1031', '1127', '1030', '816', '1095', '722', '753', '1051', '1106', '1019', '715', '886', '813', '1098', '740', '1126', '1096', '759', '1129', '705', '837', '766', '941', '846', '926', '1040', '711', '858', '1035', '1105', '836', '775
# ...

# %%
mylist=dic['1071']
print(mylist)
chemin="test/1071/study/"
for li in mylist:
  dd=os.listdir(chemin+li)

  ds = pydicom.dcmread(chemin+li+"/"+dd[0])
  image=ds.pixel_array
  cv2_imshow(image)
